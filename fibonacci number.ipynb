# %%
first=0
second=1

# %%
print('The fibonacci sequence is:')
# Out:
# The fibonacci sequence is:

# %%
while second in range (50):
    print(second,end=" ")
    first,second= second,first+second
# Out:
# 1 1 2 3 5 8 13 21 34
